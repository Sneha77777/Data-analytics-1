# %%
import pandas as pd
marks=[30,40,50,60]
s=pd.Series(marks)
print(s)
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# dtype: int64

# %%
marks=[30,40,50,60]
sub=["maths","science","hindi","english"]
s=pd.Series(marks,sub)
print(s,type(s))
# Out:
# maths      30
# science    40
# hindi      50
# english    60
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
s=pd.Series([20,30,40],index=["math","eng","social"])
print(s)
# Out:
# math      20
# eng       30
# social    40
# dtype: int64

# %%
this={"apple":10,"orange":20,"purplr":80}
s=pd.Series(this)
print(s)
# Out:
# apple     10
# orange    20
# purplr    80
# dtype: int64

# %%
import pandas as pd
marks=pd.Series([30,40,50,60],index=["maths","science","hindi","english"])
print(marks)
print(marks.shape)
print(marks.size)
print(marks.index)
print(marks.values)
print(marks.dtype)
print(marks.head())
print(marks.tail())
print(marks.describe())
print(marks.info())
# Out:
# maths      30
# science    40
# hindi      50
# english    60
# dtype: int64
# (4,)
# 4
# Index(['maths', 'science', 'hindi', 'english'], dtype='object')
# [30 40 50 60]
# int64
# maths      30
# science    40
# hindi      50
# english    60
# dtype: int64
# maths      30
# science    40
# hindi      50
# english    60
# dtype: int64
# count     4.000000
# mean     45.000000
# std      12.909944
# min      30.000000
# 25%      37.500000
# 50%      45.000000
# 75%      52.500000
# max      60.000000
# dtype: float64
# <class 'pandas.core.series.Series'>
# Index: 4 entries, maths to english
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      int64
# dtypes: int64(1)
# memory usage: 64.0+ bytes
# None

# %%
marks.unique()
# Out:
# array([30, 40, 50, 60])

# %%
marks.nunique()
# Out:
# 4

# %%
marks.value_counts()
# Out:
# 30    1
# 40    1
# 50    1
# 60    1
# Name: count, dtype: int64

# %%
import pandas as pd
marks=pd.Series([30,40,50,60],index=["maths","science","hindi","english"])
print(marks)
print(marks[3])
# Out:
# maths      30
# science    40
# hindi      50
# english    60
# dtype: int64
# 60
# /tmp/ipython-input-3129630787.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(marks[3])

# %%
import pandas as pd
marks=pd.Series([30,40,50,60],index=["maths","science","hindi","english"])
print(marks)

print(marks.iloc[3])
# Out:
# maths      30
# science    40
# hindi      50
# english    60
# dtype: int64
# 60

# %%
print(marks[1:3])
# Out:
# science    40
# hindi      50
# dtype: int64

# %%
print(marks[5:2:-1])
# Out:
# english    60
# dtype: int64

# %%
import pandas as pd
marks=pd.Series([30,40,50,60,90,86],index=["maths","science","hindi","english",'tamil','evs'])
print(marks)
# Out:
# maths      30
# science    40
# hindi      50
# english    60
# tamil      90
# evs        86
# dtype: int64

# %%
print(marks[5:2:-1])
# Out:
# evs        86
# tamil      90
# english    60
# dtype: int64

# %%
marks["maths"]
# Out:
# np.int64(30)

# %%
import pandas as pd
marks=pd.Series([30,40,50,60,90,86],index=["maths","science","hindi","english",'tamil','evs'])
print(marks)
marks["maths"]
# Out:
# maths      30
# science    40
# hindi      50
# english    60
# tamil      90
# evs        86
# dtype: int64
# np.int64(30)

# %%
print(marks["hindi":"evs"])
# Out:
# hindi      50
# english    60
# tamil      90
# evs        86
# dtype: int64

# %%
marks>80
# Out:
# maths      False
# science    False
# hindi      False
# english    False
# tamil       True
# evs         True
# dtype: bool

# %%
marks<80
# Out:
# maths       True
# science     True
# hindi       True
# english     True
# tamil      False
# evs        False
# dtype: bool

# %%
marks[marks>80]
# Out:
# tamil    90
# evs      86
# dtype: int64

# %%
marks[marks==90]
# Out:
# tamil    90
# dtype: int64

# %%
(marks>80) & (marks<90)
# Out:
# maths      False
# science    False
# hindi      False
# english    False
# tamil      False
# evs         True
# dtype: bool

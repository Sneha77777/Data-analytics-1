# %%
a=[1,2,3,4,5,5,67]
b=[1,2,3,4]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 5, 67, 1, 2, 3, 4]

# %%
a=[67,76,89,98]
a.insert(67,100)
print(a)
# Out:
# [67, 76, 89, 98, 100]

# %%
a=[1,2,3,4,5,6]
a.pop()
print(a)

a.pop(2)
print(a)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 4, 5]

# %%
a=[5,6,7,8,2,3,4,5]
a.sort()
print(a)

a.sort(reverse=True)
print(a)
# Out:
# [2, 3, 4, 5, 5, 6, 7, 8]
# [8, 7, 6, 5, 5, 4, 3, 2]

# %%
a=[34,5,6]
print(a)

c=a
c.insert(34,100)
print(c)
print(a)
b=a.copy()

b.append("*")
print(a)
print(b)
# Out:
# [34, 5, 6]
# [34, 5, 6, 100]
# [34, 5, 6, 100]
# [34, 5, 6, 100]
# [34, 5, 6, 100, '*']

# %%
a=[1,2,3,4,5,"the","amma"]
a.reverse()
print(a)
# Out:
# ['amma', 'the', 5, 4, 3, 2, 1]

# %%
x=[1,2,3];
print(x)
# Out:
# [1, 2, 3]

# %%
age1=[34,35,36,37]
age2=[35,46,58,67]
age2.insert(34,45)
age1.insert(35,100)
print(age1)
print(age2)
# Out:
# [34, 35, 36, 37, 100]
# [35, 46, 58, 67, 45]

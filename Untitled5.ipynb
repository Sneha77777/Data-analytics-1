# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
b=np.arange(1,10,4)
print(b)
# Out:
# [1 5 9]

# %%
c=np.linspace(0,1,3)
print(c)
# Out:
# [0.  0.5 1. ]

# %%
arr=np.array([[5,6,7],[2,3,4]])
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
# Out:
# 2
# (2, 3)
# 6
# int64

# %%
print(np.zeros((2,3)))
print(np.ones((1,2)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]
# [[1. 1.]]

# %%
print(np.full((2,3),7))
# Out:
# [[7 7 7]
#  [7 7 7]]

# %%
arr=np.array([12,13,14,15,16,80])
print(arr[1])
print(arr[1:])
print(arr[:2])
print(arr[0:5:2])
print(arr[-1])
# Out:
# 13
# [13 14 15 16 80]
# [12 13]
# [12 14 16]
# 80

# %%
arr=np.array([[[1,2,3],[2,3,4]],[[2,5,6],[4,5,6]]])
print(arr[1])
print(arr[1][1][2])
# Out:
# [[2 5 6]
#  [4 5 6]]

# %%
arr=np.array([12,13,14,15,16,80])
print(arr.sum())
print(arr.mean())
print(arr.max())
print(arr.min())
print(arr.std())
# Out:
# 150
# 25.0
# 80
# 12
# 24.63060426921489

# %%
arr=np.array([1,2,3,4])
print(arr+5)
print(arr-5)
print(arr*2)
print(arr%2)
# Out:
# [6 7 8 9]
# [-4 -3 -2 -1]
# [2 4 6 8]
# [1 0 1 0]

# %%
print(np.random.rand(3))
print(np.random.randint(1,10,5))
# Out:
# [0.17040089 0.8478065  0.25167845]
# [1 1 3 7 1]

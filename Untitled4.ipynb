# %%
d={"a":1,"b":2}
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
d={"a":1,"b":2}
print(type(d))
# Out:
# <class 'dict'>

# %%
student={"name":"sneha","age":21,"coursee":"ai&ds"}
print(student)
# Out:
# {'name': 'sneha', 'age': 21, 'coursee': 'ai&ds'}

# %%
student={"name":"sneha","age":21,"coursee":"ai&ds"}
print(student["name"])
print(student["age"])
# Out:
# sneha
# 21

# %%
student={"name":"sneha","age":21,"coursee":"ai&ds"}
print(student.get("age"))
print(student.get("name"))
print(student.get("marks"))
print(student.get("marks",50))
# Out:
# 21
# sneha
# None
# 50

# %%
student={"name":"sneha","age":21,"coursee":"ai&ds"}
student["college"]="gc"
print(student)
# Out:
# {'name': 'sneha', 'age': 21, 'coursee': 'ai&ds', 'college': 'gc'}

# %%
student={"name":"sneha","age":21,"coursee":"ai&ds"}
student.pop("age")
student.popitem()
# Out:
# ('coursee', 'ai&ds')

# %%
d={"a":1,"b":2}
print(d.keys())
print(d.values())
d.update({"c":3})
print(d)
# Out:
# dict_keys(['a', 'b'])
# dict_values([1, 2])
# {'a': 1, 'b': 2, 'c': 3}

# %%
squares={x:x*x for x in range(1,6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
i=1
while i<=5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i==5:
  print(i)
  i+=1

# %%
while True:
  print("hello")
  break
# Out:
# hello
